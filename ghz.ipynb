# %%
# creating a bell state from |00> 
from qiskit.quantum_info import Statevector
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator

# create an n qubit GHZ state from |0...>
def ghz(n_qubits: int) -> QuantumCircuit:
    ghz_qc = QuantumCircuit(n_qubits)
    ghz_qc.h(0)
    for i in range(n_qubits):
        if i == 0:
            continue

        else:
            ghz_qc.cx(i-1,i)
    return ghz_qc

# %%
print(ghz(5))
# Out:
#      ┌───┐
# q_0: ┤ H ├──■─────────────────
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├──■────────────
#           └───┘┌─┴─┐
# q_2: ──────────┤ X ├──■───────
#                └───┘┌─┴─┐
# q_3: ───────────────┤ X ├──■──
#                     └───┘┌─┴─┐
# q_4: ────────────────────┤ X ├
#                          └───┘
